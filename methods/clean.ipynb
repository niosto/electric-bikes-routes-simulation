# %%
import pandas as pd
import geopandas as gpd
import random
from shapely.geometry import Point

# %%
#Medellin y AMVA

filename='data/001_EOD_2017_BD_General.xlsx'
df = pd.read_excel(filename)

# %%
df.head()
# Out:
#    ID_HOGAR  ID_MORADOR   ID_CONCAT EDAD  ID_GENERO DESC_GENERO  \
# 0   1000067         396  1000067396   48          1   Masculino
# 1   1000067         396  1000067396   48          1   Masculino
# 2   1000067         396  1000067396   48          1   Masculino
# 3   1000067         397  1000067397   32          2    Femenino
# 4   1000067         397  1000067397   32          2    Femenino
#
#   DESC_ESCOLARIDAD_MAX            DESC_OCUPACION    ESTRATO  SEC_VIAJE  ...  \
# 0  Educación No formal  Trabajador Independiente  ESTRATO 3        624  ...
# 1  Educación No formal  Trabajador Independiente  ESTRATO 3        625  ...
# 2  Educación No formal  Trabajador Independiente  ESTRATO 3        626  ...
# 3              Técnico               Ama de casa  ESTRATO 3        627  ...
# 4              Técnico               Ama de casa  ESTRATO 3        628  ...
#
#   M_Principal DESC_M_Principal FREC_CANTIDAD ID_FREC_VIAJE  \
# 0           1            Auto            1.0             4
# 1           1            Auto            1.0             4
# 2           1            Auto            1.0             1
# 3          10        Caminata            1.0             1
# 4          10        Caminata            1.0             1
#
#    DESC_ID_FREC_VIAJE  COSTO_TTE_PARQ  FORMA_PAGO_PARQUEADERO  \
# 0               Anual          2500.0                     NaN
# 1               Anual             NaN                     NaN
# 2              Diario         30000.0                     NaN
# 3              Diario             NaN                     NaN
# 4              Diario             NaN                     NaN
#
#    DESC_FORMA_PAGO_PARQUEADERO TIPO_PARQUEO       DESC_TIPO_PARQUEO
# 0                          NaN            3  Lote o edificio pagado
# 1                          NaN            5               Propio(7)
# 2                          NaN            3  Lote o edificio pagado
# 3                          NaN          NaN                     NaN
# 4                          NaN          NaN                     NaN
#
# [5 rows x 55 columns]

# %%
to_ndrop = ['MUNICIPIO_O','COMUNA_O','HORA_O',
            'MUNICIPIO_D','COMUNA_D','HORA_D',
            'DESC_MOTIVO_VIAJE','DESC_MODO_TTE_E1']
df=df[to_ndrop]

renaming={'COMUNA_O':'comuna_o',
        'MUNICIPIO_O':'municipio_o',
        'COMUNA_D':'comuna_d',
        'MUNICIPIO_D':'municipio_d',
        'HORA_O':'hora_o',
        'HORA_D':'hora_d',
        'DESC_MODO_TTE_E1':'modo_tte',
        'DESC_MOTIVO_VIAJE':'motivo_viaje'
        }

df=df.rename(columns=renaming)

df=df[df['modo_tte'].str.contains(r"Moto \(", regex=True)]

# %%
# Normalizar campos

normalize = {'Regreso a casa': 'Casa', 
           'Al Trabajo': 'Trabajo',
           'Recreaci√≥n':'Recreacion',
           'Diligencia o tr√°mite':'Diligencia',
           'Acompa√±ar a alguien':'Alguien',
           'Recoger o dejar a alguien':'Alguien'}

df['motivo_viaje'] = df['motivo_viaje'].replace(normalize)

# %%
#Generacion Medellin y AMVA

df_med=df[(df['municipio_o']=='Medellin') & (df['municipio_d']=='Medellin')].copy()

amva=['Medellin','Sabaneta','Bello','Caldas','Itagui','La Estrella',
      'Girardota','Envigado','Barbosa','Copacabana']
df_amva=df[(df['municipio_o'].isin(amva)) & df['municipio_d'].isin(amva)].copy()

# %%
#Importar geojson

gdf_med=gpd.read_file("geojson/medellin.geojson")
gdf_med=gdf_med[['name','geometry']].iloc[:21]

gdf_amva=gpd.read_file("geojson/amva.geojson");
gdf_amva=gdf_amva[['name','geometry']].iloc[0:9]

# %%
def get_random_point_in_polygon(polygon):
    minx, miny, maxx, maxy = polygon.bounds
    while True:
        p = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        if polygon.contains(p):
            return [p.x,p.y]

# %%
def assign_random_point(row, gdf, other_gdf=None, municipio_col='municipio_o', comuna_col='comuna_o'):
    municipio = row[municipio_col].strip().lower()
    comuna = row.get(comuna_col, None)
    comuna = comuna.strip().lower() if comuna else None

    # Medellin or Bogotá with comuna
    if municipio in ('medellin', 'bogotá') and comuna:
        match = gdf[gdf['name'].str.contains(comuna, case=False)]
        if not match.empty:
            polygon = match.iloc[0].geometry
            lon, lat = get_random_point_in_polygon(polygon)
            return pd.Series([lon, lat])

    # Other municipios
    elif other_gdf is not None and not other_gdf.empty:
        match = other_gdf[other_gdf['name'].str.contains(municipio, case=False)]
        if not match.empty:
            polygon = match.iloc[0].geometry
            lon, lat = get_random_point_in_polygon(polygon)
            return pd.Series([lon, lat])

    # No match found
    return pd.Series([None, None])

# %%
# Generar puntos de origen y destino para medellin

df_med[['o_long','o_lat']] = df_med.apply(
    assign_random_point, axis=1, args=(gdf_med, df_amva,'municipio_o','comuna_o')
)
df_med[['d_long','d_lat']] = df_med.apply(
    assign_random_point, axis=1, args=(gdf_med, df_amva,'municipio_d','comuna_d')
)

# %%
df_med
# Out:
#       municipio_o                     comuna_o    hora_o municipio_d  \
# 28       Medellin                La Candelaria  20:00:00    Medellin
# 227      Medellin                     Guayabal  14:00:00    Medellin
# 239      Medellin                     Guayabal  09:00:00    Medellin
# 240      Medellin                   El Poblado  16:00:00    Medellin
# 434      Medellin      Corregimiento Altavista  08:00:00    Medellin
# ...           ...                          ...       ...         ...
# 87260    Medellin  Corregimiento San Cristobal  17:30:00    Medellin
# 87265    Medellin  Corregimiento San Cristobal  06:30:00    Medellin
# 87266    Medellin                   El Poblado  17:30:00    Medellin
# 87269    Medellin  Corregimiento San Cristobal  06:30:00    Medellin
# 87270    Medellin  Corregimiento San Cristobal  17:30:00    Medellin
#
#                           comuna_d    hora_d motivo_viaje  \
# 28         Corregimiento Altavista  21:00:00         Casa
# 227                  La Candelaria  15:00:00   Diligencia
# 239                     El Poblado  09:20:00      Estudio
# 240                       Guayabal  16:20:00         Casa
# 434        Corregimiento Altavista  08:05:00         Otro
# ...                            ...       ...          ...
# 87260  Corregimiento San Cristobal  17:40:00         Casa
# 87265                   El Poblado  07:00:00      Trabajo
# 87266  Corregimiento San Cristobal  18:00:00         Casa
# 87269  Corregimiento San Cristobal  07:00:00      Trabajo
# 87270  Corregimiento San Cristobal  18:00:00         Casa
#
#                   modo_tte     o_long     o_lat     d_long     d_lat
# 28        Moto (Conductor) -75.569672  6.239086 -75.627785  6.244614
# 227       Moto (Conductor) -75.585411  6.219663 -75.564959  6.252687
# 239       Moto (Conductor) -75.577267  6.226652 -75.572040  6.219370
# 240       Moto (Conductor) -75.558960  6.201331 -75.585844  6.223384
# 434       Moto (Conductor) -75.634189  6.243387 -75.626981  6.223082
# ...                    ...        ...       ...        ...       ...
# 87260     Moto (Conductor) -75.598492  6.298566 -75.650552  6.273031
# 87265  Moto (Acompa√±ante) -75.620117  6.283534 -75.561863  6.189834
# 87266  Moto (Acompa√±ante) -75.564238  6.191712 -75.640924  6.289205
# 87269     Moto (Conductor) -75.614122  6.288800 -75.621308  6.266527
# 87270     Moto (Conductor) -75.643590  6.293324 -75.620505  6.283256
#
# [4281 rows x 12 columns]

# %%
# Generar puntos de origen y destino para AMVA

df_amva[['o_long','o_lat']]=df_amva.apply(
    assign_random_point, axis=1, args=(gdf_med, gdf_amva,'municipio_o','comuna_o')
)

df_amva[['d_long','d_lat']]=df_amva.apply(
    assign_random_point, axis=1, args=(gdf_med, gdf_amva,'municipio_d','comuna_d')
)

# %%
# Exportar datos

# df_amva.to_json("results/amva.json",orient="records", indent=2)
df_med.to_json('results/med.json',orient="records", indent=2)

# %%
#Bogota

filename='data/d.xlsx'
df=pd.read_excel(filename)

# %%
# Eliminar columnas innecesarias, y normalizarlas

to_ndrop=['localidad_ori','nom_mun_ori','localidad_des',
          'nom_mun_des','hora_ini','hora_fin',
          'modo_principal_agrupado','motivo_viaje']

df=df[to_ndrop]

renaming={'localidad_ori':'comuna_o',
          'nom_mun_ori':'municipio_o',
          'localidad_des':'comuna_d',
          'nom_mun_des':'municipio_d',
          'hora_ini':'hora_o',
          'hora_fin':'hora_d',
          'modo_principal_agrupado':'modo_tte',
          'motivo_viaje':'motivo_viaje'}

df=df.rename(columns=renaming)

# %%
# Filtrar para Bogotá y transporte en motos

df=df[(df['municipio_o']=='Bogotá') & (df['municipio_d']=='Bogotá')]
df=df[df['modo_tte']=='MOTO']

# %%
# Normalzar datos en campos

normalize={' A trabajar':'Trabajo',
           ' A regresar al hogar':'Casa',
           ' A acompañar a alguien sin remuneración':'Alguien',
           ' A realizar algún trámite personal':'Diligencia',
           ' A Estudiar':'Estudio',
           ' A realizar compras':'Recreacion',
           ' A llevar y/o dejar algo':'Diligencia',
           ' Conduzco vehículo como forma de trabajo':'Trabajo',
           ' A asuntos médicos personales':'Salud',
           ' A visitar a alguien':'Alguien',
           ' A realizar actividades físicas y/o deportivas':'Recreacion',
           ' A realizar actividades recreativas y culturales':'Recreacion',
           ' A buscar trabajo':'Trabajo',
           ' A asistir actividad de tipo religioso y/o culto':'Recreacion',
           ' A acompañar a alguien con remuneración':'Trabajo'
           }
df['motivo_viaje']=df['motivo_viaje'].replace(normalize)

# %%
df_bog=df.copy()
df_bog.head()
# Out:
#           comuna_o municipio_o        comuna_d municipio_d    hora_o  \
# 31  Ciudad Bolivar      Bogotá            Bosa      Bogotá  08:00:00
# 32            Bosa      Bogotá  Ciudad Bolivar      Bogotá  18:15:00
# 80            Bosa      Bogotá         Kennedy      Bogotá  08:00:00
# 81         Kennedy      Bogotá            Bosa      Bogotá  09:52:12
# 82            Bosa      Bogotá         Kennedy      Bogotá  08:00:00
#
#       hora_d modo_tte motivo_viaje
# 31  08:45:00     MOTO      Trabajo
# 32  19:00:00     MOTO         Casa
# 80  08:45:00     MOTO      Alguien
# 81  10:37:12     MOTO         Casa
# 82  08:45:00     MOTO      Trabajo

# %%
gdf_bog=gpd.read_file("geojson/bog_ofi.geojson")

# %%
gdf_bog=gdf_bog[['LocNombre','geometry']].rename(columns={'LocNombre':'name'})

# %%
# Generar puntos para Bogotá

df_bog[['o_long','o_lat']]=df_bog.apply(
    assign_random_point, axis = 1, args = (gdf_bog, gdf_bog, 'municipio_o','comuna_o')   
)

df_bog[['d_long','d_lat']]=df_bog.apply(
    assign_random_point, axis = 1, args = (gdf_bog, gdf_bog, 'municipio_d','comuna_d')   
)

# %%
# df_bog.to_json('results/bog.json',orient="records",indent=2)

# %%
import json
with open("geojson/bog_ofi1.geojson","r") as f:
        bog = json.load(f);

# %%
del bog["type"]

# %%
for feature in bog["features"]:
    feature["type"]="Feature"
    geometry = feature["geometry"]
    geometry.rena
# Out:
# {'properties': {'OBJECTID': 81,
#   'LocNombre': 'ANTONIO NARIÃ‘O',
#   'LocAAdmini': 'Acuerdo 117 de 2003',
#   'LocArea': 4879543.3864294,
#   'LocCodigo': '15',
#   'SHAPE_Length': 0.108973020105648,
#   'SHAPE_Area': 0.000397341362785474},
#  'geometry': {'rings': [[[-74.1307544629999, 4.59335334700006],
#     [-74.1291650249999, 4.59327354900006],
#     [-74.1282584339999, 4.59327351800005],
#     [-74.1275922519999, 4.59327349400007],
#     [-74.1263517549999, 4.59325121800009],
#     [-74.1250004929999, 4.59331785100005],
#     [-74.1221429069999, 4.59356224600009],
#     [-74.1209023959999, 4.59378447500006],
#     [-74.1195068199999, 4.59411783500008],
#     [-74.117978327, 4.59451787400008],
#     [-74.1168707239999, 4.59480678900007],
#     [-74.1156745069999, 4.59516238000009],
#     [-74.1146333579999, 4.59538461100004],
#     [-74.1134371379999, 4.59580688500006],
#     [-74.1115763369999, 4.59660700600006],
#     [-74.109095254, 4.59782942100009],
#     [-74.1085675709999, 4.59794479400006],
#     [-74.108215991, 4.59801670000007],
#     [-74.1078371039999, 4.59808860300007],
#     [-74.107073006, 4.59824398900008],
#     [-74.1044560809999, 4.59619891500006],
#     [-74.1040282659999, 4.59584077500006],
#     [-74.1037060649999, 4.59545494800005],
#     [-74.103669459, 4.59530429800009],
#     [-74.1036145489999, 4.59508750600008],
#     [-74.103204473, 4.59466125600005],
#     [-74.1031165869999, 4.59472003700006],
#     [-74.102944487, 4.59477146900008],
#     [-74.1027028149999, 4.59478982300004],
#     [-74.1024977619999, 4.59479348100007],
#     [-74.1020546999999, 4.59480079800005],
#     [-74.0990845489999, 4.59491937000007],
#     [-74.0907160509999, 4.59253226400006],
#     [-74.0890048949999, 4.59181954700006],
#     [-74.0849308679999, 4.58931982300004],
#     [-74.0903617619999, 4.58140563000006],
#     [-74.0945824589999, 4.57579699500008],
#     [-74.0989479669999, 4.57886673900009],
#     [-74.1026608139999, 4.58137249900005],
#     [-74.108882311, 4.58922836000005],
#     [-74.109327559, 4.58882650100009],
#     [-74.1100655409999, 4.58865926300007],
#     [-74.1102641909999, 4.58865763800009],
#     [-74.1104455039999, 4.58865534600005],
#     [-74.1109504249999, 4.58865768000004],
#     [-74.1113153459999, 4.58865539800007],
#     [-74.1116481359999, 4.58864390400009],
#     [-74.112780503, 4.58857187700005],
#     [-74.1135734529999, 4.58851931500004],
#     [-74.1150545079999, 4.58832869100007],
#     [-74.116863211, 4.58844715500004],
#     [-74.1244714239999, 4.58995936700006],
#     [-74.1252281689999, 4.59028410000008],
#     [-74.1271566439999, 4.59184550600008],
#     [-74.1273808859999, 4.59201168700008],
#     [-74.1277704209999, 4.59232923800005],
#     [-74.1280307339999, 4.59253909300008],
#     [-74.1282904469999, 4.59265318800004],
#     [-74.128530097, 4.59271113000006],
#     [-74.1289091799999, 4.59280405600009],
#     [-74.1294694439999, 4.59294041200008],
#     [-74.1298931649999, 4.59306380200007],
#     [-74.1307481719999, 4.59335141500009],
#     [-74.1307544629999, 4.59335334700006]]]}}
